# %%
import sys
import os
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
from IPython import display
from IPython.display import clear_output
import pylab as pl
import numpy as np
from scipy.stats import ortho_group
import matplotlib.pyplot as plt
from numba import njit, jit
from time import time
# from helpers import *
from BSMBSS import *
#np.random.seed(13)
# %load_ext autoreload
# %autoreload 2

# %%
os.chdir("..")
os.chdir("./NumericalExperiments") # Change directory to read images
I = np.load('test_images.npy') # I contains 4 images.

# %%
S = I[:,[0,2,3]].T #Generate a source matrix from 3 images
print('Below are the original source images')
Subplot_gray_images(S.T) #Imshow them to observe
# Out:
# Below are the original source images

# %%
np.corrcoef(S)
# Out:
# array([[ 1.        , -0.07744917,  0.0456502 ],
#        [-0.07744917,  1.        , -0.0061411 ],
#        [ 0.0456502 , -0.0061411 ,  1.        ]])

# %%
NumberofSources = 3
NumberofMixtures = 4
# Generate Mxr random mixing from i.i.d N(0,1)
# A = np.random.randn(NumberofMixtures,NumberofSources)
A = ortho_group.rvs(NumberofSources)
X = np.dot(A,S)

# SNR = 30 # dB
# NoiseAmp = (10 ** (-SNR/20))# * np.sqrt(NumberofSources)
# NoisePart = NoiseAmp * np.random.randn(X.shape[0], X.shape[1])
# X = X  + NoisePart
# SNRinp = 10 * np.log10(np.sum(np.var(X, axis = 1)) / np.sum(np.var(NoisePart, axis = 1)))
# print("Input SNR is : {}".format(SNRinp))
print("The following is the mixture matrix A")
display_matrix(A)
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  0.427 & 0.385 & -0.818 & \\
#  -0.437 & 0.880 & 0.186 & \\
#  -0.792 & -0.278 & -0.544 & \\
# \end{bmatrix}$

# %%
print('Below are the mixture images')
Subplot_gray_images(X.T) #Imshow them to observe
# Out:
# Below are the mixture images

# %%
debug_iteration_point = 1000
gamma = np.sqrt(1 - 4e-3)
gamma = 0.998
model = OnlineBSM(s_dim = NumberofSources, x_dim = NumberofSources, beta = 1e-6, 
                  gamma = gamma, neural_OUTPUT_COMP_TOL = 1e-10, set_ground_truth = True, S = S, A = A)

# %%
model.fit_batch_antisparse(X = X, n_epochs = 1, whiten = True, neural_dynamic_iterations = 10000,
                           neural_lr_start = 0.001, neural_lr_stop = 1e-3, fast_start = True,
                           debug_iteration_point = debug_iteration_point, plot_in_jupyter = True)
# Out:
#  78%|██████████████████████████▌       | 204859/262144 [09:11<02:34, 371.35it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_596840/1981527081.py in <module>
# ----> 1 model.fit_batch_antisparse(X = X, n_epochs = 1, whiten = True, neural_dynamic_iterations = 10000,
#       2                            neural_lr_start = 0.001, neural_lr_stop = 1e-3, fast_start = True,
#       3                            debug_iteration_point = debug_iteration_point, plot_in_jupyter = True)
#
# ~/Desktop/Files/BoundedSimilarityMatching/Blind-Bounded-Source-Seperation/src/BSMBSS.py in fit_batch_antisparse(self, X, n_epochs, whiten, shuffle, neural_dynamic_iterations, neural_lr_start, neural_lr_stop, fast_start, debug_iteration_point, plot_in_jupyter)
#     245                 # Neural Dynamics: Equations (17) from the paper
#     246
# --> 247                 # u = np.linalg.solve(M @ D, W @ x_current)
#     248                 # y = self.ProjectOntoLInfty(u / np.diag(Upsilon * D))
#     249                 y = self.run_neural_dynamics_antisparse(x_current, y, W, M, D, neural_dynamic_iterations, neural_lr_start, neural_lr_stop, neural_OUTPUT_COMP_TOL, fast_start)
#
# ~/anaconda3/lib/python3.9/site-packages/numba/core/serialize.py in _numba_unpickle(address, bytedata, hashed)
#      27
#      28
# ---> 29 def _numba_unpickle(address, bytedata, hashed):
#      30     """Used by `numba_unpickle` from _helperlib.c
#      31
#
# KeyboardInterrupt:

# %%
Wf = model.compute_overall_mapping(return_mapping = True)
Y = Wf @ X
Y.shape, X.shape, S.shape

# %%
CalculateSIR(A, Wf)

# %%
Y_ = signed_and_permutation_corrected_sources(S.T,Y.T).T

# %%
print('Below are the extracted images')
Subplot_gray_images(Y_.T) #Imshow them to observe
